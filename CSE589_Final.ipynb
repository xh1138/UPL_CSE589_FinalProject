# %%
# !git clone https://github.com/tonyhuang2022/UPL.git
# !git clone https://github.com/KaiyangZhou/Dassl.pytorch.git
# Out:
# Sun Oct 26 23:28:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             42W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# %cd /content/Dassl.pytorch
# !git reset --hard ac6e44194b2f90e325f477aadd6d9bc3a92ce255
# !pip install -r requirements.txt
# !pip install torch==1.8.1 torchvision==0.9.1

# !python setup.py develop
# Out:
# /content/Dassl.pytorch
# HEAD is now at ac6e441 leave 2 spaces for comment
# ...
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0)
# ERROR: No matching distribution found for torch==1.8.1
# running develop
# /usr/local/lib/python3.12/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# ...

# %%
# %cd /content/
# %cd UPL
# !pip install -r requirements.txt
# Out:
# /content
# /content/UPL
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/UPL


# !rm -rf ./data
# !ln -s /content/drive/MyDrive/CSE589/Final_Project ./data


# !rm -rf temp_analyze_results_miltiple
# !mkdir temp_analyze_results_miltiple
# Out:
# Mounted at /content/drive
# /content/UPL

# %%
# %cd /content/UPL/scripts
# !bash get_info.sh sscaltech101 anay_rn50 end 16 -1 False
# Out:
# /content/UPL/scripts
# Run this job and save the output to ./output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/nctx16_cscFalse_ctpend/seed1
# 2025-10-26 23:24:02.967945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761521042.991290   10792 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761521042.998144   10792 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761521043.015593   10792 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd /content/UPL/scripts
# !bash upl_train.sh sscaltech101 rn50_ep50 end 16 16 False True rn50_random_init
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch [11/50][40/48]	time 0.045 (0.074)	data 0.000 (0.027)	eta 0:02:18	loss 0.8413 (0.6539)	acc 84.3750 (82.5000)	lr 1.844328e-03
# epoch [11/50][45/48]	time 0.040 (0.072)	data 0.000 (0.025)	eta 0:02:14	loss 1.3711 (0.6695)	acc 68.7500 (82.3611)	lr 1.844328e-03
# epoch [12/50][5/48]	time 0.044 (0.205)	data 0.000 (0.155)	eta 0:06:23	loss 0.8423 (0.6714)	acc 81.2500 (84.3750)	lr 1.809017e-03
# epoch [12/50][10/48]	time 0.044 (0.133)	data 0.000 (0.085)	eta 0:04:08	loss 0.7896 (0.6514)	acc 78.1250 (84.3750)	lr 1.809017e-03
# epoch [12/50][15/48]	time 0.046 (0.104)	data 0.000 (0.057)	eta 0:03:13	loss 0.7461 (0.6499)	acc 87.5000 (83.9583)	lr 1.809017e-03
# epoch [12/50][20/48]	time 0.047 (0.093)	data 0.000 (0.045)	eta 0:02:51	loss 0.3767 (0.6107)	acc 84.3750 (84.2188)	lr 1.809017e-03
# epoch [12/50][25/48]	time 0.110 (0.087)	data 0.062 (0.039)	eta 0:02:40	loss 0.8438 (0.6085)	acc 71.8750 (83.5000)	lr 1.809017e-03
# ...

# %%
# %cd /content/UPL
# !zip -r upl_results.zip output/
# Out:
# /content/UPL
#   adding: output/ (stored 0%)
#   adding: output/sscaltech101/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/nctx16_cscFalse_ctpend/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/nctx16_cscFalse_ctpend/seed1/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/nctx16_cscFalse_ctpend/seed1/log.txt (deflated 62%)
#   adding: output/sscaltech101/UPLTrainer/rn50_ep50_16shots_EQULE_True__rn50_random_init/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/rn50_ep50_16shots_EQULE_True__rn50_random_init/nctx16_cscFalse_ctpend/ (stored 0%)
#   adding: output/sscaltech101/UPLTrainer/rn50_ep50_16shots_EQULE_True__rn50_random_init/nctx16_cscFalse_ctpend/seed6/ (stored 0%)
# ...

# %%
# !cp -r /content/UPL /content/drive/MyDrive/UPL_full_backup_2025_10_26

# %%
# !cp -r /content/Dassl.pytorch /content/drive/MyDrive/Dassl_pytorch_backup_2025_10_26

# %%
# %cd /content/drive/MyDrive/Dassl_pytorch_backup_2025_10_26
# !pip install -r requirements.txt
# !python setup.py develop

# %cd /content/drive/MyDrive/UPL_full_backup_2025_10_26
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Dassl_pytorch_backup_2025_10_26
# ...
# running develop
# /usr/local/lib/python3.12/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
# ...

# %%
# %cd /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
#!bash get_all_info.sh sscaltech101
# !bash get_info.sh sscaltech101 anay_rn50 end 16 -1 False
# Out:
# /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# Run this job and save the output to ./output/sscaltech101/UPLTrainer/anay_rn50_-1shots_random_init/nctx16_cscFalse_ctpend/seed1
# 2025-11-01 06:05:05.762323: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-01 06:05:05.779562: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761977105.801124    5633 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %cd /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# !bash upl_train.sh sscaltech101 rn50_ep50 end 8 2 False True rn50_random_init
#!bash upl_train.sh sscaltech101 rn50_ep50 end 32 1 False True rn50_random_init
# Out:
# /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# Run this job and save the output to ./output/sscaltech101/UPLTrainer/rn50_ep50_2shots_EQULE_True__rn50_random_init/nctx8_cscFalse_ctpend/seed1
# 2025-11-01 06:24:42.501421: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-01 06:24:42.518789: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761978282.540200   12834 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %cd /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# !bash upl_train.sh sscaltech101 rn50_ep50 end 8 2 False True multiple_models_random_init
# Out:
# /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# Run this job and save the output to ./output/sscaltech101/UPLTrainer/rn50_ep50_2shots_EQULE_True__multiple_models_random_init/nctx8_cscFalse_ctpend/seed1
# 2025-11-01 06:14:34.949479: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-01 06:14:34.966893: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761977674.987955    8277 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# %cd /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# !bash upl_test_existing_logits.sh sscaltech101 rn50_ep50 end 32 1 False True multiple_models_random_init
# Out:
# /content/drive/MyDrive/UPL_full_backup_2025_10_26/scripts
# 2025-11-01 06:25:32.223005: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-01 06:25:32.240291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761978332.262105   13484 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
